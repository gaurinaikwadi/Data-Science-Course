# %%
a=5

# %%
b=32

# %%
a+b
# Out:
# 37

# %%
name="gauri"

# %%
print("Hello world")
# Out:
# Hello world

# %%
#this is a comment

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
type(name)
# Out:
# str

# %%
a="200"

# %%
b="400"

# %%
a+b
# Out:
# '200400'

# %%
int(a+b)
# Out:
# 200400

# %%
int(a)+int(b)  #typecasting
# Out:
# 600
