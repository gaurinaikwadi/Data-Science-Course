# %% [markdown]
# # String & String Methods in Python

# %%
name="gauri"

# %%
name
# Out:
# 'gauri'

# %% [markdown]
# **String methods**<br>
# some basic methods of string

# %%
name.upper()
# Out:
# 'GAURI'

# %%
name.endswith("ri")
# Out:
# True

# %%
name.count("b")
# Out:
# 0

# %%
name.count("a")
# Out:
# 1

# %%
name.lower()
# Out:
# 'gauri'

# %%
name.find("ri")
# Out:
# 3

# %%
name.islower()
# Out:
# True

# %%
name.split()
# Out:
# ['gauri']

# %% [markdown]
# **String Indexing and Slicing** <br>
# Indexing starts at 0.

# %%
name[0]
# Out:
# 'g'

# %%
name[-1]
# Out:
# 'i'

# %%
name[0:2]
# Out:
# 'ga'

# %%
name[:3]
# Out:
# 'gau'

# %%
name[3:]
# Out:
# 'ri'

# %% [markdown]
# **String Immutability** <br>
# Strings cannot be changed after creation.

# %%
name[0] = 'i' #error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 name[0] = 'i' #error
#
# NameError: name 'name' is not defined
