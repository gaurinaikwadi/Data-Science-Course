# %%
import pandas as pd

# %%
# Create a Pandas Series containing the values 10, 20, 30, 40 using the default index

series= pd.Series([10,20,30,40])

# %%
series
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# Create a Pandas Series containing the values 100, 200, 300 with custom index labels a , b , and c .

series= pd.Series([100,200,300], index=["a","b","c"])
