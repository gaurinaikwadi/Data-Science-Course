# %%
def avg(a,b):
    return(a+b)/2

# %%
avg(2,3)
# Out:
# 2.5

# %%
def avg(a,b=0):    #default arguements will always be last in bracket
    return(a+b)/2

# %%
avg(9)
# Out:
# 4.5

# %%
def avg(a,b,c=9,d=8):
    return(a+b)/2

# %%
avg(2,4)
# Out:
# 3.0

# %%
def greet():
    print("hello world")

# %%
greet()
# Out:
# hello world

# %%
# when python dosent retun anything then it considered as "none"

# %%
None   #reserved keyword in python
