# %%
a = input("enter user choice value of a")
# Out:
# enter user choice value of a 79

# %%
b = input("enter user choice value of b")
# Out:
# enter user choice value of b 78

# %%
a+b   # output will be as string
# Out:
# '7978'

# %%
int(a)+int(b) # output will be addition of two intergers (typecasting)
# Out:
# 157

# %%
age = int(input("enter ur age"))
# Out:
# enter ur age 89

# %%
price = float(input("enter price"))
# Out:
# enter price 89

# %%
age + price
# Out:
# 178.0
